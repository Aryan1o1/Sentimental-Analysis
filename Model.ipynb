# %%
import pandas as pd 
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
import nltk
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
import re
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score
import pickle

# %%
df = pd.read_csv("balanced_reviews.csv")

# %% [markdown]
# # EDA Activities

# %%
df.head()
# Out:
#    overall                                         reviewText  \
# 0        5      Great nephew loved!!! Very fast delivery!!!!!
# 1        5                     well made boot, fits perfectly
# 2        5  Perfect fit. Good quality. (Do not put in dryer.)
# 3        5  I bought these for my 2 year old girl and she ...
# 4        5  Great backpack.  I wanted to get a backpack th...
#
#                    summary
# 0               Five Stars
# 1               Five Stars
# 2                Nice bra!
# 3  Better than I expected!
# 4          Great backpack.

# %%
df.tail()
# Out:
#         overall                                         reviewText  \
# 791995        1      One time use and did not perform well for me.
# 791996        1  I ordered these shoes before, ad they were ama...
# 791997        1                              The size is too large
# 791998        1  Has cardboard like feeling while wearing them....
# 791999        1  Its like sticking paper to your boobs. It show...
#
#                                                   summary
# 791995                                           One Star
# 791996         ad they were amazing. Cute with everything
# 791997                                           One Star
# 791998  Feel stiff and cheap, doesn't work with screen...
# 791999                                     waste of money

# %%
df.shape
# Out:
# (792000, 3)

# %%
df.isnull().any(axis=0)
# Out:
# overall       False
# reviewText     True
# summary        True
# dtype: bool

# %%
df[df.isnull().any(axis=1)]
# Out:
#         overall                                         reviewText  \
# 276           5                                                NaN
# 303           5                                                NaN
# 530           5                                                NaN
# 1277          5                                                NaN
# 1916          5                                                NaN
# ...         ...                                                ...
# 784201        2  Bracelet buttons are not "Strong enough"..Keep...
# 788806        1                                                NaN
# 790074        1  Insta exact size just not what I expected the ...
# 790897        1  Horrible.....I ordered the white and they were...
# 791061        1                                                NaN
#
#                  summary
# 276           Five Stars
# 303     Wonderful watch!
# 530           Five Stars
# 1277          Five Stars
# 1916          Five Stars
# ...                  ...
# 784201               NaN
# 788806          One Star
# 790074               NaN
# 790897               NaN
# 791061          One Star
#
# [781 rows x 3 columns]

# %% [markdown]
# ##  Handling Missing Values

# %%
df.dropna(inplace =True)

# %%
df.overall.value_counts()
# Out:
# 3    263836
# 2    131939
# 1    131876
# 4    131849
# 5    131719
# Name: overall, dtype: int64

# %%
df['overall'] == 3
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 791995    False
# 791996    False
# 791997    False
# 791998    False
# 791999    False
# Name: overall, Length: 791219, dtype: bool

# %%
df = df[df['overall'] != 3]

# %%
df
# Out:
#         overall                                         reviewText  \
# 0             5      Great nephew loved!!! Very fast delivery!!!!!
# 1             5                     well made boot, fits perfectly
# 2             5  Perfect fit. Good quality. (Do not put in dryer.)
# 3             5  I bought these for my 2 year old girl and she ...
# 4             5  Great backpack.  I wanted to get a backpack th...
# ...         ...                                                ...
# 791995        1      One time use and did not perform well for me.
# 791996        1  I ordered these shoes before, ad they were ama...
# 791997        1                              The size is too large
# 791998        1  Has cardboard like feeling while wearing them....
# 791999        1  Its like sticking paper to your boobs. It show...
#
#                                                   summary
# 0                                              Five Stars
# 1                                              Five Stars
# 2                                               Nice bra!
# 3                                 Better than I expected!
# 4                                         Great backpack.
# ...                                                   ...
# 791995                                           One Star
# 791996         ad they were amazing. Cute with everything
# 791997                                           One Star
# 791998  Feel stiff and cheap, doesn't work with screen...
# 791999                                     waste of money
#
# [527383 rows x 3 columns]

# %%
df['Positivity'] = np.where(df['overall'] > 3, 1, 0)

# %%
df
# Out:
#         overall                                         reviewText  \
# 0             5      Great nephew loved!!! Very fast delivery!!!!!
# 1             5                     well made boot, fits perfectly
# 2             5  Perfect fit. Good quality. (Do not put in dryer.)
# 3             5  I bought these for my 2 year old girl and she ...
# 4             5  Great backpack.  I wanted to get a backpack th...
# ...         ...                                                ...
# 791995        1      One time use and did not perform well for me.
# 791996        1  I ordered these shoes before, ad they were ama...
# 791997        1                              The size is too large
# 791998        1  Has cardboard like feeling while wearing them....
# 791999        1  Its like sticking paper to your boobs. It show...
#
#                                                   summary  Positivity
# 0                                              Five Stars           1
# 1                                              Five Stars           1
# 2                                               Nice bra!           1
# 3                                 Better than I expected!           1
# 4                                         Great backpack.           1
# ...                                                   ...         ...
# 791995                                           One Star           0
# 791996         ad they were amazing. Cute with everything           0
# 791997                                           One Star           0
# 791998  Feel stiff and cheap, doesn't work with screen...           0
# 791999                                     waste of money           0
#
# [527383 rows x 4 columns]

# %%
df.Positivity.value_counts()
# Out:
# 0    263815
# 1    263568
# Name: Positivity, dtype: int64

# %% [markdown]
# # Data Cleaning

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
df['reviewText'][0]
# Out:
# 'Great nephew loved!!! Very fast delivery!!!!!'

# %%
review = re.sub('[^a-zA-Z]',' ', df['reviewText'][0])

# %%
review = review.lower()
review = review.split()

# %%
review = [word for word in review if not word in set(stopwords.words('english'))]

# %%
review
# Out:
# ['great', 'nephew', 'loved', 'fast', 'delivery']

# %%
ps = PorterStemmer()

# %%
review = [ps.stem(word) for word in review ]

# %%
review = " ".join(review)

# %%
review
# Out:
# 'great nephew love fast deliveri'

# %%
corpus = []
for i in range(0, 527383):
    review = re.sub('[^a-zA-Z]',' ', df.iloc[i,1])
    review = review.lower()
    review = review.split()
    review = [word for word in review if not word in set(stopwords.words('english'))]
    ps = PorterStemmer()
    review = [ps.stem(word) for word in review ]
    review = " ".join(review)
    corpus.append(review)

# %%
corpus
# Out:
# ['great nephew love fast deliveri',
#  'well made boot fit perfectli',
#  'perfect fit good qualiti put dryer',
#  'bought year old girl love love comfort love boot made sturdi rubber look realli cute price great',
#  'great backpack want get backpack would last sever school year think go meet expect heavi duti pocket thing student need get back forth school',
#  'use everi day smell great scent weaken sand bit brush use',
#  'nice pant',
#  'first pair jazz shoe daughter break fit comfort left blister even first wear danc approx hour time',
#  'got shoe elderli mother fit great well made easi velcro closur let snug right keep sure foot walk',
#  'love keen newport sandal durabl water proof part shoe ware year also nice come varieti color',
#  'comfort',
#  'overal bought husband christma one love got earli make sure fit give pair back wrap',
#  'ask got order thank',
#  'hubbi shirt get littl worn order coupl pretti nice wish pocket price care',
#  'noth like real thing real leather',
#  'wear birkenstock classic lieu neuroma surgeri work great year wear anyth els though love',
#  'bag well made lot pocket even larg enough hold inch laptop loop bag go suitcas handl',
#  'realli like work great',
#  'love carhartt shirt long sleev made durabl materi still soft comfort wear carhartt everi day whether long sleev short great fit high qualiti long last',
#  'fit great differ color',
#  'fit perfectli size bought feet take day becom accustom hard cork sole love feel great could walk mile',
#  'fit expect nd time bought boot bought pair son coupl year ago still good shape wear time know hold well',
#  'great materi perfect qualiti',
#  'great shoe go order',
#  'solid comfort smell qualiti leather plan use sno seal well sued version shade brown happi went color great leather feel hold condit find much better sued although sued comfort floppi soft took day adjust slightli tougher beeswax leather also fenc bushacr noth come close comfort natur crepe sole clark origin desert boot',
#  'perfect',
#  'love price prime day ship great exactli pictur',
#  'father law love carhartt brand got bunch carhartt item christma enjoy great thick materi fit perfect say soft comfort long enough work stay tuck move around comfort materi awesom lot outdoor work mechanist type work shirt durabl stand work man abus clean nice stain easili also tear easili want super comfi durabl shirt one',
#  'rd pair realli enjoy boot easi feet stand long period time also wear wood waterproof feet stay dri pair wear look fourth pair',
#  'receiv pair shoe exact day order ontrac love shoe made real leather eleg design comfort walk especi thorlo men sock order amazon perfectli match',
#  'husband son law happi purchas boot comfort exactli need work',
#  'second pair shoe own sole old pair final worn year final start leak littl summer problem get good fit newer model keen put tri differ one cabela spring one fit like use set anoth year',
#  'boot take beat mani other asolo line break period boot littl time own mani pair fugit never foot issu box one time walk mile hr period waterproof great sole wonder durabl mark simpl pepper plastic part reason gone pair littl decad keep buy',
#  'awesom',
#  'bought size fit perfect without sock hope stretch littl wear super warm cozi comfort comfi ugg',
#  'bought husband xma love wear everywher like origin',
#  'amaz boot fit well look great purchas pair last month order full size smaller normal shoe size',
#  'husband need durabl comfort pant hammer loop util pocket replac fall apart jean fit bill everi way',
#  'want lauren wallet forev found great price snatch beauti',
#  'made mistak own origin seiko dive watch sinc use hundr deepwat dive year actual use bezel time decompress stop without problem stop dive ten year ago due health issu went snorkel trip key west recent use watch littl know gasket ring dri thu watch start fog took jewel got home told open case mechan fell could fix even call seiko said thing came across watch amazon price sold could pass think paid watch glad made invest mayb one last littl longer',
#  'excel',
#  'love desert boot pair like young teenag love em love em mani color select make even better clark alway expect comfort qualiti',
#  'love love love regret turtl fur would recommend age group',
#  'comfort pad insol like wear slipper look cool red black white wear everyth',
#  'actual fit head nice print side',
#  'great sport bra dd normal wear ddd bra sport bra fit perfectli although strap adjust tight enough short torso great support moder activ comfort could wear day shirt',
#  'awsom qualiti wash super well fast ship definit order',
#  'better fit local specialti shop better select',
#  'work well good size seen retail use',
#  'fit boyfriend perfectli wide feet typic tough find shoe great highli recommend',
#  'purchas shoe love wore everi day went vacat disney world shoe bother feet walk mile day park would give star',
#  'comfort great work stand concret day',
#  'sever shirt comfort',
#  'tri pair size worn past',
#  'best underwear ever comfort snugli feel like wear noth throughout day also breath like underwear use see hold year wash bewar counterfit item five order two came counterfit plain open plastic bag way tell new use stich gave away fake like other report nasti',
#  'bought bag last year broke toe crutch three month well made found kipl bag bought throughout year enough room heavi wallet cell phone key small thing larg compart also zipper compart paper flat object remov velcro small pocket front took much space small snap would work better use front pocket pen store shoulder strap insid bag take way much space detach leav home bag adjust hip well like wear hip bone start measur inch sinc adjust wider width lot strap hang back wrap back around stuff insid pocket design hold shoulder strap ye expens think price dollar less qualiti amaz',
#  'said somewhat small although littl snug instep high one comfort nice shoe',
#  'work secur nyc great caus keep realli warm pleas',
#  'order variou style scrub top style comfort practic work clinic room lift bend pocket need dicki tend wash wear best realli hold multipl wash problem stain would recommend',
#  'wear shoe day work hour constantli feet go place seem weird wear cute shoe like work hey want look nice time',
#  'nice sturdi belt',
#  'good qualiti fit realli well would buy',
#  'never play price pair shoe',
#  'realli like rigg workwear jean interestingli order nd pair receiv similar style pair jean carhartt ok also certain carhartt also return item sinc tag suppos make sure wash first',
#  'love cinch jean wash last well much better bean other husband love comfort style seem relax waist well get smaller size waist big baggi seat jean pant wear cinch white label',
#  'honestli shoe good pair shoe still look new quit',
#  'good materi love open seam panti part great need use restroom',
#  'great qualiti',
#  'need length avail order fit well warm enjoy anyway',
#  'great watch last year old one still good small band holder broke got new one recommend',
#  'work els say',
#  'usual order bra onlin one fit perfectli',
#  'particular attach outfit two kid enjoy much wife beg wear someth els',
#  'sever sciatica l lay l shift forward nd pair month use one home one wear work comfort less pain numb right hip shin foot recommend product peopl need good support light weight shoe recommend prior buy go run shoe store check shoe csr look bottom current shoe let watch walk see walk',
#  'go pair boot sever pair clark year worn brand alway tend come back clark particularli desert boot keep look prime extra care condit',
#  'sandal mani color wore last black pair worn year go sandal',
#  'nice chain held well',
#  'fantast',
#  'love boot take time break deal fit well sole heavi actual like hear boot hit ground walk stylish jean dress could pull leather strong worn rain twice tri soak wish boot made high qualiti',
#  'discov reef ginger flip flop year ago buy flip flop sinc arch support plu fabric upper make comfort day walk summer irrit toe squish time lose support usual last full summer season realli best',
#  'great product',
#  'pair wonder fast dri short glad still avail bought first pair year ago feel soft like cotton moistur wick properti supplex lb waist order medium want smooth fit snug leg sometim rise littl sit length perfect waist perfect roll wash cold water regular cycl throw dryer low shrink fade highli recommend',
#  'live without price save know winter easi use well worth money',
#  'love sebago docksid comfort last year',
#  'shoe famou shoe shia labeouf charact sam witwicki wear pair exactli black samba film transform reveng fallen ashton kutcher wear adida samba film valentin day wear pair shoe feel star model adida r shoe oldest one sold model excel combin style comfort besid price quit access realli recommend buy shoe sure regret',
#  'purchas mother gift wear everyday use hous shoe everi time show hous unannounc',
#  'fit expect comfort feel seem like last long',
#  'love second pair purchas own first pair year work upper leather still look new sole pretti worn',
#  'got husband limit select choos due narrow feet gener get athlet shoe difficulti lace great solut say comfort easi put take plu alreadi gotten sever compliment',
#  'littl watch everyth claim updat batteri die replac cr batteri yet encount problem watch gripe backlight glow dark nevertheless still love watch',
#  'perform like champ first night',
#  'best look versatil windbreak ever second one first last mani year six word requir review',
#  'son realli love',
#  'fit like width accomod break time',
#  'second pair exact boot actual went tri coupl boot chang pace came back comfort wear day',
#  'purchas pair florida around year ago final get fatigu point unsightli still function fine wife let leav hous excit find amazon never worn comfort durabl sandal live south louisiana deal mud rock sand cement asphalt swamp etc rip come apart kept chug along definit keep buy longa avail',
#  'globe castro comfort nice look men shoe th pair purchas famili love',
#  'ray band never fail meet standard one best sunglass compani help certain color standout lot easier see',
#  'break period afterward super comfort',
#  'good expect',
#  'daughter love shoe',
#  'realli like fit true size',
#  'love minnetonka slipper actual wore last pair throw keep feet warm comfi winter',
#  'love pant use dress pant everyday pant',
#  'great valu great gift',
#  'wear year great price sole kinda thin ok shoe shop add thin rubber sole look great comfort current pair design',
#  'chanc wear item world yet tri item insid hous heel high sexi run small comfort chose item two common color one pair shoe match outfit price right like look good sexi definetli shoe',
#  'comfort',
#  'gave girl friend boot ice fish keep feet warm ice hour get cold feet',
#  'comfort best underwar mani year',
#  'birkenstock alway perfect fit soft wonder treat',
#  'nice fit',
#  'th pair ecco year ago get walk across showroom floor difficult went orthoped surgeon said surgeri fast went nd ortho ask live told auto sale look shoe balli loafer said shoe wear like drive car without shock absorb said spend money get pair ecco fast forward date problem knee sinc start wear work',
#  'good cualiti',
#  'qualiti product fit well comfort',
#  'difficulti find attract comfort wide width shoe reason price simpli imposs rural area absolut ticket feather weight day smart casual wear ship even super saver rapid arriv perfect condit probabl purchas anoth pair futur use eventu wear could find brown',
#  'order amazon prime show two busi day later got love case sunglass great come case clean cloth small blurb care new shade mayb standard sunglass like someon use wear sunglass kept break quit pleas qualiti case sunglass got mm one read review said mm bought kid fals lb mm work perfect mm would work like bigger lens unless larger person fuller face big cheek think mm nice',
#  'perfect comfort love',
#  'bought daughter wear time materi goe toe cloth comfort look like go last summer',
#  'love design qualiti comfort definit purchas keen shoe',
#  'love watch bought granddaught',
#  'great product',
#  'good qualiti price correct',
#  'outstand look feel great alerg metal rash watch sinc wear titanium watch md best',
#  'great favorit comfort',
#  'excel watch design top line bulova great valu two bulova highbridg seri stainless two tone unfortun longer manufactur thank amazon com',
#  'ask',
#  'six avail color think like serious older push get pocket need pair great pocket fish shirt need cover pocket spare problem step scale doctor nearli lb heavier step shower nine pocket plu hammer loop doubl knee ripstop fabric adult loos fit scream comfort wait spring wear ranger short',
#  'fit medium regular expect extrem satisfi',
#  'alway sperri great show fit consist look great last',
#  'got brown shade lighter hershey bar thick warm stepdad love work barn',
#  'true go amazon sent pair send back alway conveni love style tie annoy sperri shoelac time awesom',
#  'love watch worn everyday sinc got love color even though start fade side care love like th timex watch love everyon would recommend',
#  'amazingli good qualiti best child costum ever bought grandson love take fire station get photo kid grandson whoever play fireman buy disappoint',
#  'far live hype worn coupl time comfort fit well invis cloth concern hand wash instruct let face want hand wash underwear far held well garment bag hand wash cycl machin lay flat dri',
#  'wear day night problem',
#  'perfect',
#  'good qualiti fit true size ship arriv time fashion thank',
#  'bought elderli father mobil issu love easi slip go say comfort break time love look much nicer person exactli look substanti traction easi put comfort great look exactli search',
#  'mention review pant differ color durabl opinion worth',
#  'typic dicki reliabl brand',
#  'great littl stiff expect due tough shell carhartt extrem warm love far',
#  'love shoe podiatrist th pair bought plan get',
#  'get blue',
#  'fit shoe easili stay well heavili construct nice tall satisfi purchas',
#  'bought shoe wear train martial art shoe size first tri shoe somewhat concern shoe bit big wear sock train hour slightli thicker sock bc even thin sock still felt like shoe littl lose feet felt great suffer blister shoe realli gripe floor perform great',
#  'excel price tough work watch keep good time easi read',
#  'great design fit helmet better due thin materi top',
#  'rd pair carli sandal bought past year differ color comfort go almost outfit wear servic excel quick great price could find shoe store',
#  'promis',
#  'bra great break becom realli comfort',
#  'nice wear men women fit perfectli gold fun parti',
#  'bought teen son love flashi yet classi',
#  'great qualiti product',
#  'third pair flip flop first one got worn wear year two becam slipperi sole second one got black third brown wear day feet hurt wear get one spend lot money flip flop worth put wish list amazon let know sale got brown one half price wear go rain yoga mat part soak water like spong',
#  'great jean worn long time',
#  'great sock superb pad strong high qualiti',
#  'perfect ofr danc recit fit foot ankl without sag love purchas',
#  'order size husbi usual wear small order next size fit recommend order size larger unless like tighter fit',
#  'im clog nut order one glad oh comfi ador color tri one like',
#  'arriv day earli great shoe around run littl larger least anyway',
#  'nice wow alot pocket',
#  'awesom',
#  'bought sandal year ago move oversea west africa live warm hot climat want good support sandal everyday live also look cute stylish love look shoe found one frustrat thing sand would constantli get hard get annoy wear often got pregnant grew grew sandal one give support need wear everi day thank birkenstock creat support sandal',
#  'bought mario halloween fit great head overs look suit mario charact',
#  'good shoe',
#  'comfort long last',
#  'birkenstock shoe great someon foot problem arthriti toe well plantar fasciiti birkenstock pain liter non exist say enough good compat ici street howev wish bottom grip prevent extrem slip ici surfac previous own pair birkenstock sandal wore year needless say durabl shoe process order anoth sandal',
#  'spend workday feet extrem comfort shoe',
#  'great wish could find well',
#  'describ pictur love practic love thing celtic pewter love bracelet',
#  'sp parti yr old son bought go spi kit wonder fun kid even adult fun play',
#  'good item',
#  'gracia',
#  'exel option protect children',
#  'order rago women high waist long leg shaper know size work rago size closer vintag size order normal dress size rago compani vaniti size like modern women cloth compani must order shapewear base hip size mean order two size larger dress size shaper feel firm smooth dress skirt despit compress find comfort wear major tip hosieri clasp detach',
#  'great',
#  'pretti fit well like',
#  'fit perfectli velcro closur',
#  'great shoe purchas great price comfort fit expect',
#  'alway fit perfect',
#  'great fit panti fit expect bind pull line show cloth look full coverag comfort tri',
#  'size e ww fit like comfi slipper realli soft great cushion support',
#  'happi purchas everyth boot wonder buy wear sure may take awhil',
#  'love shoe whether town trail shoe fashion function fantast product',
#  'say boot fit good qualiti good would recommend boot whatev intend',
#  'want say star suppos insid',
#  'usual reef sandal high qualiti perfect fit',
#  'fit perfect far comfort pair flip flop ive ever definit order',
#  'descent qualiti fit good year old done enjoy heck purchas glove face shield also good qualiti',
#  'order size ware levi fit perfect great qualiti warm amazon best price',
#  'son love costum receiv ton compliment actual fire fighter qualiti perfect wash well money well spent',
#  'bali best mistakenli thought would tri brand bad idea bra fit comfort give good support',
#  'awesom watch larg wrist hairi arm watch small wrist pretti much hairless arm shave part wrist hair pull',
#  'pant far comfort fit realli like',
#  'real nice sweater',
#  'best shoe ever',
#  'great costum',
#  'good soccer shoe',
#  'need',
#  'bought work electr apprentic fit well wear still get broke abl stand kneel crawl problem',
#  'summer rn matter bc need get dough real quick know im say',
#  'amaz watch never use calcul work',
#  'ador great price order next size soon thank great deal',
#  'cart light yet durabl fold flat compact easili fit carri use haul medic equip basebal park negoti bump pothol without problem defin worth price especi need conveni compact',
#  'love',
#  'perfect good busi',
#  'cathartt run littl big shrink much alway order medium year old son fit perfectli',
#  'terrif deal live',
#  'boot comfort love mine month sad put soon summer',
#  'good sun visor hat suppos',
#  'great product well made',
#  'love qualiti purs last ever friend famili share view',
#  'good look timepiec gave husband birthday love',
#  'got today look great without scratch plastic updat issu',
#  'great slipper would highli recommend',
#  'alway good stuff boyfriend want carhartt',
#  'good',
#  'love chuck love must buy',
#  'ultra lightweight rel easi set hard shorten wristband especi like dual time zone set use road trip albuquerqu price budget buster would highli recommend',
#  'great time piec',
#  'first pair final wore second pair exactli great first expect noth less birkenstock',
#  'worn skagen watch long remeb thin aspect watch love look great also',
#  'convert long time die hard guy suprem subsequ purchas two pair worth extra buck two great deal amazon thank',
#  'husband love sandal fit perfectli comfort third pair durabl',
#  'wintertim sometim get littl chilli side toss sweatshirt nice warm',
#  'great use amazon',
#  'second pair rainbow flip flop first pair still great condit want second pair differ color style love',
#  'bra good qualiti fit right seller advertis could done better buy store',
#  'wear hat hat fit fine adjust cord would fit slightli larger head even band insid hat terri cloth kind materi probabl good comfort want hat fish open water summer keep sun neck think job fine',
#  'love shoe liter wear model color past six year fourth pair amount time wear everi singl day year rain shine want last longer sure waterproof everi month order keep dri awhil start soak water make rubber around toe begin separ happen first pair start treat spray avoid failur problem experienc heel cup break artifact realli rough put shoe probabl step back often',
#  'well pleas purchas gift husband attach timex watch great',
#  'beauti color',
#  'simpl review watch fit despit variou size band case look neat glass allow watch recharg hardwar littl cheap price work fine good deal rate five price',
#  'amaz gift come cute pouch realli heavi look like expens gift',
#  'bought watch reason citizen eco drive one best watch brand smaller men watch someon skinni wrist sick huge wrist watch watch watch year love best watch ever own time alway right stylish simpl heavi larg year wear everi day still scratch durabl band also comfort like watch much consid buy anoth one anoth color band',
#  'last forev littl tight top',
#  'amaz heel super sexi',
#  'ador warm',
#  'work awesom great valu',
#  'fit bill halloween costum held rough tumbl carniv fun paintbal',
#  'love pair younger rediscov amazon comfi keep feet warm well built last thru winter far',
#  'fantast condit batteri work visibl number attract classic watch date sweep second easi read',
#  'got wife want float heart necklac thought one look bit uniqu glad went love problem chain bit short silver extens work great',
#  'like wear sweatshirt bit loos perfect size order anoth one color size differ venu fit snug like would definit buy brand',
#  'granddaught love ballet shoe fit perfect great qualiti wear time evan danc four year old imagin beat take still look new great product',
#  'hard find pant live excit find amazon durabl husband love',
#  'love serious super comfi walk pretti much wear pregnant comfi bought last summer still look amaz comfort buy whenev wear sign wear far',
#  'good',
#  'great bra style know alway fit maidenform still make run amazon',
#  'great comfort durabl shoe wear day would recommend run true size width',
#  'everyth perfect',
#  'realli great look cargo short unfortun return way big easi return though',
#  'great fit soft bad dexter discontinu replac next gener raquel shoe comfort foot surgeri soft extrem import order size larger shoe size',
#  'need line work remov three rattl snake deer ranch week two differ speci tarantula crawl leg scare',
#  'product one best sport sock ever use protect foot injuri thick layer cushion also absorb sweat jogger design also nice low anklet appear wear shoe two set near futur ps sorri poor english',
#  'nice jacket',
#  'absolut beauti pendent smaller expect fit stone good thing mum kid one twin mum love much wear everyday great present mom totoal recommoend',
#  'shoe fit comfi littl roomi wide foot',
#  'second timex indiglo watch own purchas first one mani year ago replac watch good look kept perfect time money great buy',
#  'love uber comfort',
#  'arriv quickli nice qualiti smooth silki look feel hope last one wear rate beyond women like thigh hi seem practic definit look good hope fashion go back legwear bare leg nice stock look dressi classi',
#  'order least half size smaller run big',
#  'like surpris keep wind ride',
#  'northeast hound snow ice slush rain winter thank lucki star invest boot everi time easter even snow flurri come blow water proof problem trudg slush tri get subway car also super warm even worn without sock becom stapl winter wardrob travel around northeast work amaz walk main nyc know wait long invest alway go winter boot',
#  'one tri wed dress david bridal much afford price',
#  'ear set amaz deal absolut beauti larg enough see amaz color silver sparkl bright sorri purchas favorit citrin stun',
#  'beauti watch teacher need check time want carri cell phone time strap serv jewelri mani watch purpos wear red bordeaux lot one hit',
#  'wife love',
#  'well enjoy clock consid good servic follow buy good casio',
#  'alway fit well fit intojean pant look nice',
#  'old pair final die bit worri size order pair worri fit perfectli love new inner sole perfect day never leav hous',
#  'shoe awesom',
#  'could happier shoe gift sister love easi spirit traveltim shoe great price super fast ship',
#  'shoe good qualiti fit accord size chart high arch howev arch normal birkenstock shoe high arch birkenstock clog love look feel shoe howev',
#  'excel product love pmm',
#  'read review decid order one size larger normal fit perfectli',
#  'arriv time fit perfectli materi great',
#  'littl smaller size work',
#  'comfort sandal use beach vacat versatil enough nice casual dinner hang pool',
#  'love fit perfectli help round bump dress without restrict',
#  'isba classic rayban need much comment line rayban good option without much detail',
#  'husband love definit worth everi penni',
#  'love boot want wear school everyday definit cont buy timberland',
#  'love',
#  'order wallabe got time amazon alway time buy frm amazon fo sure lovin shoe',
#  'like order got wrong size ok us uk approx wear type review found feet like space',
#  'rockport good shoe',
#  'husband love shirt hard find',
#  'much better worth extra dollar offer much support hold pant plu easier shoulder kind cut much comfort',
#  'best thing shoe slip without bend help also comfort waterproof sole hold much dirt shallow tread thing dislik think littl pricey',
#  'aresult great stock pretti sheer primari red color stay uo lot better cheap stock bought match anoth piec lingeri work perfectli',
#  'tri find brown shirt make shirt comic con find one shirt color pictur exact fit expect',
#  'fit look good',
#  'use frequent sever soccer season still perfect get muddi rins big enough size cleat bought toggl fasten string pull',
#  'easi easi feel great',
#  'high visibl beefi bike ride beat hane beefi durabl qualiti construct american apparel style shirt skinni geek want pay shirt make feel cool among hipster friend haha kid american apparel good stuff price ridicul',
#  'shirt fine collar littl tight sure expand wear',
#  'bought husband sinc first pair worn broke exact great qualiti come expect highli recommend',
#  'bought gift recipi pleas hard find true dark black jean work perfectli',
#  'ok small line top face watch includ light face',
#  'bought go along halloween outfit perfect fit nice person good qualiti son love wear even halloween',
#  'total satisfi',
#  'sofa three piec leg would slide would separ uncomfort posit problem order two set safe side glad shini finish blend steel sofa leg perfectli',
#  'odd size x em fit perfectli',
#  'best sport bra size fantast bustier woman',
#  'best work boot hand wolverin boot suck last pair year fact bring throw away still good shape apart right hand sole come slightli',
#  'complain purchas product may rd price paid time today go wish knew go drop low love everyth shoe recommend anyon look class comfort qualiti',
#  'hard believ watch look even better wrist pictur web stun job bulova exactli expect bulova watch qualiti design second none price rang note small wrist tall man took two link bracelet use adjust clasp perfect fit know style mani watch larger face wider bracelet smaller statur small wrist like think appreci look fit timepiec',
#  'second pair bought design black brown love',
#  'goood',
#  'best littl leather shoe new walk littl feat kid bought grandson',
#  'great product deliv advertis',
#  'first pulsar watch bought nearli yr ago worn almost daili still run although show exterior wear batteri replac everi yr yr ago yr ago seiko outlet store near us bought pulsar seiko watch famili satisfi valu qualiti style reliabl seiko watch review purchas swz similar function appear yr old pulsar except face color gold vs white watch suffici larg tell time easili larg appear bulki view photo watch amazon initi concern abil distinguish gold hand gold face clearli visibl gold white differenti better amazon pictur reveal problem far month use prefer gold hand white face much expens gold silver style swz watch enabl worn gold silver accessori style suitabl daili dress formal wear style watch band problem free past purchas',
#  'love feel feet keep feet warm comfort get home work need winter would recommend anyon need light slipper wear get home work long hard day anyth',
#  'wonder shoe extrem comfort would recommend highli anyon look purchas casual shoe great price',
#  'bought son stomp around mud great durabl',
#  'son put walk around hous leg shoe fit littl weird work',
#  'great list',
#  'great boot compar danner acadia solid construct slip mud squeak smooth floor',
#  'boot fantast littl hesit buy mani bad review even state knock off third pair doc exactli hope leather stiff cours break period normal brand love height lace zipper fit perfect foot bed comfort thrill',
#  'seem like good belt leather suppl strong buckl good qualiti',
#  'perfect size clariti add pendant new grandbabi ad famili',
#  'awesom boot get black',
#  'pant better expect materi stitch high qualiti sure last order pair disappoint',
#  'order size grandson need size fit would expect size fit grandson love',
#  'div id video block r iojfbd yh c class section space small space top mini video block div input type hidden name valu http imag na ssl imag amazon com imag g eyzbia mp class video url input type hidden name valu http imag na ssl imag amazon com imag kyvgirql png class video slate img url nbsp even though typic prefer silver decid go gold great retro convers piec watch call dog beep',
#  'item describ',
#  'perfect',
#  'black black chuck look great wore wed groomsmen wear standard white black one made great pic',
#  'perfect',
#  'good fit soft',
#  'love water proof indigo wear everi day',
#  'exactli look',
#  'fast ship great product',
#  'thank u',
#  'fit prefect',
#  'bought last pair lost vacat great product last age',
#  'look sandal sinc spring thought cute saw ladi actual wear cuter person sooooo comfort wide toe box return first pair order shoe half size smaller usual wear great',
#  'purchas daughter love beginn fit somewhat true size',
#  'love love love buy use slipper longer walk barefoot omg never take serious bad may come back anoth pair cozi comfort wear without sock hous great versatil shoe sketcher sixth sketcher brand shoe ive purchas month daughter got pair bday grand daughter start pre k rest mine',
#  'love boot look similar frye boot decid instead order size smaller recommend fit perfect broken day leather great quickli get worn look feel love everyth',
#  'send first pair back never own pair irish setter shoe first pair littl small would say run half size small compar allen edmund said size right shoe great comfi warm look great built well',
#  'best jean market great fit',
#  'realli comfort boot fit glove expect good qualiti swat boot realli great purchas',
#  'om hindu celtic knot pendant pretti much true pictur nice weight size thought littl round though mine flat nice',
#  'happi purchas',
#  'great product great servic',
#  'look good nice n comfort',
#  'nice pair shoe',
#  'great jacket price light jacket comfi liner',
#  'nice product seller',
#  'love seem somewhat smaller keen own venic mayb feel differ overal great shoe swear keen brand',
#  'convers classic collect black low top convers wore home hospit born bought fresh pair everi year sinc like everi pair own purchas disappoint typic wear size alway fit perfectli',
#  'etni alway given product last year continu wear one look differ great product great comfort great look',
#  'great work belt',
#  'one best boot own open box smell good qualiti leather came look piec togeth stitch way good qualiti boot bet two year boot mayb take extra care',
#  'great watch beat seiko dive watch money',
#  'price cotton love walk though run sport buy',
#  'work well easier less messi use silver polish',
#  'realli like cotton polyest elastan feel fantast super soft give',
#  'break experi fit great anticip get comfi',
#  'like look pant daughter like fit plan buy futur thank',
#  'nice purchas beat price',
#  'cute costum son love look like best qualiti good enough dress fun fun littl small hat snug overal still ador',
#  'great boot',
#  'expect',
#  'pack cube awesom travel keep everyth organ easi locat suitecas love bag shoe dirti laundri get coupl extra gift',
#  'keen good still fine far expect brand good chang futur',
#  'alway buy bloch danc shoe littl ballerina',
#  'awesom fit',
#  'mani pair size alway true vegan version fit littl snugger comfort shoe',
#  'love weight neck warmer neck warmer one materi thick two two stand better neck keep place keep warm wash cloth attract lint',
#  'comfort work boot own less store price pretti much brainer fond dicki sole seem last near long also aggress tread pattern prefer noth wors haul half pound hitchhik dirt around side told sever peopl trendi look definit trendi',
#  'love shoe comfort fit calf jean smaller calf issu boot larg area fit great look great like multipl color good',
#  'like much fit expect',
#  'awsom fit comfort work boot',
#  'simpl silver ring exactli hope girlfriend love good busi good product',
#  'nd pair walk shoe first pair still oper season look purchas rockport shoe comfort brand durabl select size width take narrow rockport one manufactur still offer narrow shoe amazon price fast ship also add valu shoe',
#  'great bra great fit wear beig one time shirt blous slightli sheer comfort one go bra wear someth clingi top cup edg show wear recommend',
#  'fit expect stiff tight neck love',
#  'great costum kid',
#  'happi product although wish label plu size pregnant',
#  'comfort stylish great pair short jean khaki definit good weekend shoe',
#  'love love love bra first strapless bra actual stay weight loss throughout life let say girl perki bra make look good strapless cloth',
#  'want order',
#  'need costum work well fit lot stretch uncomfort worn long period time expect overal great price great product',
#  'fab',
#  'fit perfect wear women order men awesom',
#  'product amaz buy amazon com easi like recommend',
#  'order red bow tie pm got next day prime ship item excel qualiti work well danc perform use also purchas arm guarder match perfectli',
#  'awesom jean',
#  'nice shoe father love',
#  'quick shipment look good',
#  'realli great overal take littl time get comfort wear eight ten hour day top foot feel littl tight long heel toe perfect',
#  'man love fit comfort wear qualiti seem pretti good',
#  'qualiti comfort style eas attribut thing associ van brand shoe realli classic',
#  'love pair',
#  'look wind resist water proof warm deep winter coat one get tall one fit right fit great like wear armor use militari way better anyth ever gave',
#  'love r first pair ever bought r amaz price great',
#  'watch advertis consid low price great featur expect would recommend other',
#  'bought month back quit satisfi shoe comfort requir much break highli reccomend tri also footb remov make easier custom foot shape size person left ad tongu pad satisfi',
#  'great valu boyfriend love',
#  'classic sunglass never quit alway well made alway style mani pair glass sinc frame fragil care need make last',
#  'im wed coordin walk mile wed go to',
#  'great fit good qualiti',
#  'order husband lost dexter due cancer treatment difficult time tie shoelac happi say remiss hooray shoe noth duh easi put take though made heal lot comfort chemo left fingernail peel mess strap make fasten shoe easi painless though alway tough time find comfort shoe flat feet say cushion good get thank propet',
#  'talk comfort item entir transact quick painless return next pair',
#  'made metal durabl bought second one made well',
#  'normal buy convers littl big fit decent littl room left purchas women men great tini bit bigger expect that okay comfort clean look',
#  'thank excel product receiv expect',
#  'well made first time get brand hope last long',
#  'love shoe',
#  'excelent',
#  'look snake look great fit good qualiti stuff back rubi',
#  'got shoe amazon love normal wear fit perfectli run half size larg otherwis wear shoe day without problem',
#  'great shoe need new job requir skid resist shoe also comfort shoe stand mani hour speedi deliveri came day expect thank amazon',
#  'pleas quick ship',
#  'realli like watch featur timer countdown multipl lap stopwatch indiglo light definit need read instruct abl use function direct clear easi follow extens use featur yet far watch realli help time train',
#  'love watch love way feel wrist substanti think leather band look perfect also quit comfort one reason purchas watch indiglo featur wake quit frequent night great check time sincer jame brown',
#  'need lion costum fit bill soooo cute love would recommend one',
#  'realli amaz choe fix angl put top casual eleg great made also look great materi',
#  'love minnetonka moccasin wear year continu comfort buy one half size smaller usual stretch bit mold feet take care last year go',
#  'excel',
#  'great fit',
#  'nice sever past size chang use order two size larger waist normal wear order fit way like true dicki lee way big perfect way size along',
#  'ok',
#  'clark awesom',
#  'excel shoe good price quit pleas',
#  'pleas',
#  'product nice good',
#  'purchas fifth pair shoe year period believ say',
#  'great shoe happi purchas',
#  'someth work like item work well realli nice put bracelet easi use',
#  'second pair rainbow first pair style last summer near constant wear like first pair new one requir three wear get strap broken creat blister instep except sandal well worth price much comfort haviana',
#  'pretti ring quit compliment friend stranger look delic yet strong',
#  'great expect good cut nice color well fit good price good seller never gap said pack highli recommend',
#  'son love watch smaller size still water resist size work great deliveri time great condit',
#  'comfort super warm light weight wear past week northeast bitter cold feet toe toasti good traction walk recommend',
#  'great qualiti shirt one exact pattern five year pattern still bright shirt shrunk deterior husband probabl shirt mountain never disappoint shirt year old still worn check beauti pattern avail',
#  'thank',
#  'love boot cute comfort ware everywher mani said ran small normal size bought size',
#  'perfect fit',
#  'pant fit well like wear pant littl higher kid ride navel like em seem wear reason well shrink much dryer',
#  'feel good larger feet',
#  'best tee shirt ever snd year old',
#  'cozi comfort shoe winter home got dolloar great deal',
#  'bouught husband ra feet comfort shoe',
#  'son love fit great appear good qualiti hat thing like indiana jone brand insid abl remov label',
#  'happi camper comfort sandel ever order sever color found shoe search',
#  'alreadi pair inch histor jump boot brown amaz boot dress boot got wear work great much comfort foot bed jump boot lug sole necessari work mostli traction look great good mirror shine toe heel cap',
#  'comfi love slipper',
#  'sperri year bought wear boat white deck natur mark boat deck also wear boat jean short wear comfort becom get wet seem hurt either highli recommend',
#  'classic simpl watch look great anyth dress ladi like underst eleg especi worn everyon size cheap look bling watch timex alway reliabl daughter borrow job interview got job think watch help',
#  'would purchas rubber boot fast deliveri',
#  'beauti mom need someth easier get get go bathroom night otherwis wonder slipper comfort pretti',
#  'great shoe',
#  'recommend anyon work outdoor',
#  'saw shoe sale retail store size home look amazon cours found right away arriv quickli great retail comfort wear time',
#  'husband entir satisfi pant wonder could go amazon order spring wardrob man life perfect everi way',
#  'love em',
#  'pretti cover',
#  'fit perfectli real deal',
#  'favorit bra read recommend bra look buy glad final wear c challeng find bra size actual fit one fit like dream support amaz say enough support fabric perfect substanti thick also feel like pad breast would definit buy',
#  'love top fit nice blue color perfect',
#  'love cat boot great except realiz short boot',
#  'great fit',
#  'fit expect wife realli love enjoy look assess play get friski durabl wash delic let air dri',
#  'littl peopl dangli leg cute gotten mani compliment pink stone bright pictur fine prefer paler stone bang around normal wear tear littl arm leg come cute sturdi',
#  'great product slip snow ice',
#  'work well',
#  'item exactli describ fast ship',
#  'fit expect would buy',
#  'good dress sock fall qualiti good sock worn well',
#  'cloth larg wonder metal use',
#  'watch guy fan automat dive watch own omega seamast well seiko monster price amaz valu like big watch need someth presenc wrist grand diver deliv huge watch ou get use size feel right older model miyota movement keep fantast time cosc standard better seiko good omega new bracelet fantast doubl safeti latch thick stainless hing amaz touch watch price blue face look black purpl blue depend upon ambient light room attract spend omega requir servic year would cost sever hundr dollar sold grand diver look better imho keep good time great water resist die year certainli cheap enough get anoth although heard miyota seiko movement bullet proof long last neg slight one bezel littl looser would like ratchet one way tight seiko certainli terribl fact wear grand diver everi day gave seiko monster son th birthday realli understand deep discount invicta price system feel watch worth list retail serious think get anoth keep stash case model discontinu',
#  'shi run small purchas two size larger yo fit great zuma line danc light provid need support',
#  'wish hue would offer fun color qood stock',
#  'rd time order shoe differ size kid grown love shoe',
#  'love shoe first order true size slightli short swap half size comfort even wear sock winter good arch support look realli cute jean highli recommend',
#  'beauti watch expect watch perpetu function work show review',
#  'product order good fit good price good color deliveri easi better valu depart store discount store',
#  'boot exactli describ detail fit great would recommend boot other',
#  'measur correctli want snug abl get love get complement time',
#  'great price good deliveri fit expect',
#  'great replac strap tactic briefcas purchas origin strap came bag fail within week need replac found metal plastic hook hint stress bag strap meet middl part strap contact shoulder durabl neopren make strap work like cadillac neopren grip shoulder part wear also flex stretch walk like jostl bag get transfer shock absorb take beat month use sever trip daili work shown sign wear tear highli recommend replac strap good better origin hand well worth price',
#  'ammaz bookbagg word amaz realli recomend book bag everi one outstand woow',
#  'color togeth look realli cool first thought realli small wear realli arent definit comfort nose around ear expect cool',
#  'great product',
#  'fit like glove bought item son never take good qualiti comfort good traction snow nice product',
#  'need go someth specif perfect fit without bulki chest pocket need',
#  'great hat item describ love',
#  'super comfort perfectli fit',
#  'alway want watch seen gizmodo look feel even better imagin everyth even common watch',
#  'nice product meet spec expect highli recommend',
#  'best bra ever could sell serious better support sport bra better coverag minim everyday bra wear say enough posit bra wear gym everyday life wear anyth els cri ever stop sell style',
#  'well cushion sock high qualiti expens would recommend howev',
#  'bought st pair year ago still look great want red realli well made fit insert',
#  'husband absolut love order order',
#  'darker color amazon ad indic make pleas prompt ship',
#  'great buy',
#  'dainti yet easi read wrist band littl snug uncomfort',
#  'love',
#  'shoe fit littl girl chunki wide foot perfectli',
#  'want red convers year ampute wear brace leg better support shoe fit brace crush fault shoe compani sent need return heart break thought',
#  'super comfi love em',
#  'great valu great product',
#  'great boot worth price friendli feet',
#  'first explain titl get realli itchi metal jewelri one advertis hypoallergen hypoallergen also extrem comfort dial easi read even better get mani compliment watch mother accus spend much watch translat compliment mom speech mother pearl dial hint shine easi read hand long enough time clear know sometim tini littl hand suggest direct dial perfect marriag beauti function itch',
#  'love',
#  'surprisingli fit perfectli hard buy cloth especi shoe line unless know exactli get paid much wors qualiti wors fit wore day make feet sweati cramp toe would definit recommend anyon got nerv damag surgeri make harder find comfort shoe',
#  'love perfect arriv promis',
#  'daughter wear abl order larg fit right work great wax museum project school thing apron littl smaller pictur possibl bought larg girl pictur smaller regardless still work great',
#  'right item right price right great gear',
#  'perfect sock peopl exercis lot normal sock wear two pair time keep feet pad cool comfort sock wear one pair perfect give exercis sock switch thorlo',
#  'saw scarf episod duel surviv get one protect sun somewhat cold highli recommend product',
#  'perfect size color expect',
#  'ridicul comfort say tag felt moment put updat wore year almost everi day month year still wearabl',
#  'beat birkenstock comfort support',
#  'black comfort want wear shoe',
#  'like fine',
#  'great style build qualiti featur quick set year batteri make life easi',
#  'perfect',
#  'beach blue darker one pictur bit disappoint look fit perfectli tri got noth complain item came earlier expect date well thank',
#  'son footbal team love use jacket see boy still use jacket got name embroid big hit gift coach team',
#  'order preemi babi boy hard find preemi cloth regular store took chanc order great qualiti nice thicker materi seam sturdi overal great qualiti item hesit recommend anyon absolut buy cloth compani futur arriv quickli fit hope would',
#  'big fan dicki outdoor gear men sock product alway held expect jean receiv also superb product certainli order compani great servic high end product',
#  'pant fit',
#  'fit great buy',
#  'ten pair color rememb scotch guard white one like step puddl white shoe repel dirt water absolut favorit shoe',
#  'second pair keen definit recommend order half size bigger wider feet like venic h much better wider feet high arch newport previou pair wore day walk around disney week feet hurt bit',
#  'great shoe',
#  'awesom product alway',
#  'trouser fit perfect flexibl worn without belt adjust tab side',
#  'realli review return run small amazon return easi',
#  'sever nightgown love new color beauti hold well wash wash',
#  'great materi comfort length perfect would recommend anyon',
#  'second one watch first own approxim year watch us militari luminox casio watch automat wind wind motion arm batteri replac worri fail inopportun time everi year send back seiko servic seiko open watch servic seal back factori standard guarante accuraci minut month replac old one due older model made certain part longer avail still releg yard work watch sport event see rolex use time tenni golf precis time import swim track field split second time requir see seiko omega use',
#  'bought bag best friend previou ameribag extrem worn excit get new one distress nylon great love new storag featur ipad insid friend design bag bag use everyday',
#  'brought son find mall fit love came earlier expect',
#  'son love boot',
#  'beat good pair chuck comfort stylish',
#  'fit well look good feet happi',
#  'perfect everi way',
#  'use casio watch ironman wore never total happi sever year bought anoth timex ironman love much easier use use batteri rather casio also much larger display great watch',
#  'fit thin tall son like lucki jean like decid tri style',
#  'fit well good qualiti prompt deliveri good price happi',
#  'thank',
#  'love im flat foot that effect arch',
#  'bought husband busi love doesnt use comput time know would work nice guy carri total afford',
#  'comfort boot keep feet warm dri',
#  'extrem soft high qualiti sweatshirt afford price',
#  'son love boot wear other dealer sold great price could afford confort must work boot fit great style use dealer',
# ...
#  'alway carhartt fit great well made shirt',
#  'love much got style hawaii hike beach walk etc without foot fatigu love',
#  'daughter crazi shoe ad plu arriv schedul due date order',
#  'use work stall backyard barn subzero temp love zip get warm feel bit claustrophob still cover cheek face',
#  'shirt realli like comfort tight',
#  'great beauti sandal',
#  'well one levi jean everyth expect',
#  'return larg order size smaller',
#  'fit great materi right weight',
#  'feel fantast wear ever wear',
#  'shoe comfort pretti bought sever pair past year complaint get smelli could wear much',
#  'dad big foot sometim fit great made wonder father day gift',
#  'awesom would highli recommend',
#  'good shoe look nice feel great',
#  'search long hard shoe glad order everi aspect great attract fit perfectli comfort want',
#  'keen best brand shoe ever own',
#  'comfort shoe bought last year wear readi bedtim',
#  'perfect fit',
#  'ye big',
#  'fun colour littl nephew great valu',
#  'like second help learn tell time good product seem durabl enough year old',
#  'fanci function bullet proof product real valu amazon cost twice amazon price store',
#  'comfort pant fit right happi purchas',
#  'aneribag user lover sinc discov live hawaii actual abl bare fit ipad air thin protect case make nice took week get stretch slightli order fit care break zipper love purpl color size durabl well made use one daili month show wear expens given design durabl worth',
#  'work perfectli waterproof soften transport tote madewel thank',
#  'exactli suppos',
#  'husband love carhartt shirt fit great like pocket love carhartt brand long wear',
#  'two levi hybrid trouser purchas via amazon prime great pair jean worn dress dress heavier set bodi type thick build pant levi consid slim fit use levi skinni jean chang name',
#  'absolut love spiga style chain make perfect choker wear dress stun gotten sever complement style mm mm perfect alon thinner chain love charm pendant rate buy one length year',
#  'alway excel qualiti',
#  'excel fit alway boot buy',
#  'wear pant summer job wore degre weather comfort could expect seam pant clearli durabl jean fabric lightweight still durabl feel like length might littl long drag ground would probabl order one inch shorter next time avail seriou issu fit perfectli baggi tight also look stylish beat heck pant landscap hold fine order soon',
#  'soooo comfi',
#  'feel good',
#  'bought one year ago love get second one still materi expect one last anoth seven eight year',
#  'worn year take abus well never take mine get abus pretti bad',
#  'order awesom',
#  'good qualiti fit well bit warm summer perfect fall winter',
#  'got wife realli like look like good qualiti seem wife hardest descis color get',
#  'great fit qualiti',
#  'love order onyx color love worn nonstop past day comfort look great',
#  'love bag actual bought two teenag son husband former militari excit abl find easili',
#  'reason alway buy russel athlet tee shirt alway correct fit price right order except thank',
#  'wear calcutta year everi day best lightweight polar fish around sun glass ever super clear glare water',
#  'nice watch',
#  'granddaught th birthday love plan wear formal dress weekend cute',
#  'pleas watch thu far problem screen clearli show time second day date comfort easi set wear watch everyday year littl wear tear damag also worn swim shower coupl time problem review complain screen get water fog experi found matter watch get howev much say water resist watch complet water resist would never recommend intent wear watch water unless realli need even say water resist swimmer gambl dice matter watch say water resist chanc eventu get water screen especi natur wear tear time overal realli like watch would recommend star',
#  'comfort great fit',
#  'still gave slipper star well made true size littl small howev stretch real leather time fit pretti nice love insid true sheepskin line creat smell fake materi slipper mayb consid buy size bigger wear unless narrow foot',
#  'realli nice denim pant hope make year come creas make look nice wash insid cold water fade much intend order anoth pair',
#  'nice nice',
#  'comfort love sandal extrem well made buy year',
#  'realli like short bit longer length inch top knee nice fit baggi also pocket realli import order anoth pair',
#  'bag great woman age five foot five big like huge comput size messeng bag small room essenti dog cat mom school teacher writer artist need sketch book journal wallet sunglass book line dmv market small day plannerthi bag fit stuff perfectli great bag everi day put cross bodi slide like cross bodi bag constantli reach chase around littl heart beatsfrom kid school dog dog parki need someth sturdi run play bag meant combat hold well break like bag near price fianc eacut saw bag said want borrow sinc could look nice either male femal would take wed romant date man would carri daili meet daili life essenti carri look us magazin what bag even celebr own onethat got idea purchas one said sinc high school late still use bag',
#  'love product perfect color comfort fit great look feel definit buy highli recommend',
#  'love shoe',
#  'compar ray ban design brand doubl cost regret mine immedi command better half order anoth pair updat notic receiv mm mm order problem lean face may critic',
#  'well pleas product advertis shop well pleas product advertis shop',
#  'classic',
#  'good',
#  'lb fit great chest length littl tight arm forearm',
#  'sock wonder men long feet fit perfect',
#  'daughter love',
#  'order size b fit bit big super comfort color perfect',
#  'littl big soooo comfort cushion sole ador',
#  'love great garden',
#  'love product expect wait start use',
#  'wear shoe whenev snow rain perfect cold weather year still somewhat good condit',
#  'servic excel continu buy recommend friend famili',
#  'realli like fit style pant comfort easi care would highli recommend purchas',
#  'like expect fast ship',
#  'great costum son year got lot compliment costum made thin materi perfect enough layer halloween',
#  'bought boot son love flat wide feet brand boot favorit receiv huge amount love purchas',
#  'go sunglass order multipl pair sunglass amazon fabul fit perfectli extrem durabl lost one pair croaki ocean nice go onlin immedi order replac amazon much flatter origin wayfar',
#  'bought father wore first cruis look perfect said fit well true size',
#  'money expect neat watch exceed expect regardless small inset dial beauti nice weight water resist casement band great wear constantli thank valu casio',
#  'rain waterproof work shoe comfi would anoth one shoe eleg stylish ye waterproof',
#  'good deal great shoe',
#  'nice shoe lightweight',
#  'real hillbilli great fit great product',
#  'order great size perfect packag great problem time great product',
#  'use model year love night light alarm wish strap differ hate either',
#  'big head littl snug end strip mark forehead warm tight knit trap heat well',
#  'shrink make sure room shrink worn brand perfect',
#  'like vampir glass use halloween prop nice price look good thank good look prop',
#  'nice',
#  'love teacher bring laptop paper grade book home lesson plan still lot room stuff great purchas',
#  'descript say silk touch expect softer close knit finish actual pretti much piqu style noth silki shirt comfort well made look great differ expect matter like still get would recommend size unless want snug fit usual buy xl local learn go size inexpens shirt web xl fit perfectli',
#  'love sneaker comfort go everyth',
#  'item exactli expect',
#  'love wrangler jean fit thicker normal new normal fabric roomi crotch combin make great pair jean oliv color uniqu jean worn casual busi pant good price',
#  'great qualiti great price heavi qualiti great live northern state could warm california florida',
#  'bought niec welcom babi brother hospit love parent famili hospit staff uniqu realli made niec feel like part experi great qualiti great size even leav hospit excit use doctor dress cloth highli highli recommend',
#  'columbia great depend qualiti w sleev fit right glad bought wish columbia would tall men sale awhil',
#  'worn work everi day coupl decad fit right requisit pocket coupl year replac one two time could get better shirt will pay doubl complet satisfi valu get shirt',
#  'ador soft comfi slipper great eas morn chill even',
#  'buy sooner tl dr great shoe fit big feet comfort feel like clog slipper someon valu time oh hell lazi slip shoe hold heel foot put leav work stick foot back tend destroy heel shoe comput tech mostli wear sneaker casual shoe year thought get sort shoe year held huge feet usual new balanc fit foot correctli without break period say except rule got first time around peopl said ran big small went perfect also arch support first felt weird feel like someth know live without also felt like broken pair sinc first mayb second day wore complaint pick ton sand salt ice snow tread keep drop good half hour get destin winter home take shoe door notic work chair crunch sand park lot importantli howev wear coupl week day everi day still slip eas feel floppi feet walk weird terrain wish guess make pair mesh toe area get littl warm time see easi way design overal well guess fact plan buy second pair speak',
#  'shoe gf love',
#  'love moccasin soft yet practic even look good casual skirt sole give necessari structur',
#  'realli good',
#  'great watch unbeliev price',
#  'great boot man buy pair everi year wear everyday love',
#  'perfect fit alway',
#  'great',
#  'great product',
#  'much softer other dicki work pant',
#  'great fit durabl wear sometim',
#  'great boot keep buy timbo buy pair everi year get everyth put still old pair dirti stuff still life',
#  'good',
#  'got tonight order morn love amazon snug ugg suppos broken wear got size sinc first pair also',
#  'order friday even got tuesday around pm came perfect',
#  'glad read review great moc order save send back wrong size pretti solid close toe shoe even pair minnetonka boat moc order per review perfect fit think moc run narrow side fine unlin sued sure stretch conform feet sued line great bc wear without sock push sock cover foot see work size lot support issu expect moccasin got grey darker medium grey comfi right box expect get lot wear excel price think order brown well thank review thank amazon',
#  'slightli big still great product perfect kelli green',
#  'purchas happi comfort sock good qualiti great price heather gray color attract difficult find store packag like',
#  'like watch saw pictur happier see deliv birthday present could happier compliment watch work well causal dress would wear everyday work compliment dress perfect price definit good buy',
#  'wife love',
#  'good fit well made',
#  'want',
#  'order husband unisex see mani woman wear color least style well made thick sturdi materi small logo side butterfli girl hat small notic say one size fit tag insid say larg littl tight husband sure actual larg woman ever size differ woman men hat like feel price worth color pretti spot one pic vent hole plu husband strong spf rate know hat spf rate uv ray actual go hat without spf sound nice sure matter great hat around feel last quit',
#  'expect work great leav shoe shine previous',
#  'sister pirat parti niec birthday year want pay much pirat costum costum look similar price rang poorli construct costum one go fall apart even get wear look improv costum seen',
#  'good',
#  'great shirt great price wore wash never shrank thank guy ill buy',
#  'want',
#  'happi qualiti mink ear muff expect price extrem reason say enough great product quick deliveri',
#  'absolut ador shoe need casual black flip flop fit bill perfectli wear pool around hous groceri shop everywher super comfort attract look',
#  'shoe fit expect return gift longer need morgan miller custom servic impecc issu full refund definit would buy',
#  'beauti co worker love',
#  'nice shirt nice fit great price christma littl pricey right want purchas',
#  'love boot buy winter boot',
#  'great shirt',
#  'live australia want shape wear sexi tight get hot great order medium order size keep still give nice smooth look slimmer look size smaller would great australian think us quit shore',
#  'wear bra year still best bra ever worn lift seper keep breast move extremli good support bra make look like breast job',
#  'love',
#  'great',
#  'gorgeou item float heart pendant diamond stun low price read review peopl complain lost long term ship issu paid standard ship item front door next day one year anniversari gift girlfriend know love type person want rock hang kneck would enjoy eleg necklac diamond larg enough notic distract peopl attent necklac come nice box ribbon tie around case necklac beauti found good find like want alot littl would definitli purchas one kind offer',
#  'love worn year best slip ever worn tri like',
#  'wear pantyhos year year size qualiti comfort chang look fabul wash wear well comfort',
#  'comfort soft wear time also love slap back heel walk',
#  'good',
#  'husband tall hard find jacket look like littl boy jacket fit perfectli qualiti wrangler would highli recommend wrangler rug wear jacket',
#  'comfort hook',
#  'watch came quickli beauti fantast packag sinc christma gift earli comment oper',
#  'comfi',
#  'daughter ask boot year realli hesit buy girli girl perfect pair wore get feet anymor fit give away shop new pair great buy',
#  'great daughter love deliveri right schedul',
#  'like comfort materi fact flip flop light anoth great thing fabric insid strap make even comfort wear lot recommend anyon like fun casual comfi flip flop great job sanuk',
#  'simpl good shirt',
#  'great sneaker',
#  'daughter love super cute make sure get right size almost got men would women glad doubl check',
#  'son love tri sleep let set right next bed like real fireman',
#  'everyth fit fine',
#  'bought dad birthday prize tad long howev love say comfort',
#  'perfect gift',
#  'exactli want',
#  'good qualiti',
#  'hush puppi fit like glove maximum comfort support dialect feet get anoth pair within day',
#  'met spec',
#  'great pair shoe run around restaur night',
#  'second pair one rare occas wear first pair duke golden retriev mistook chew toy shrede although put valiant fight size right money comfort new pair great qualiti equal first pair ship fast deliv unit state postal servic sunday packag good',
#  'comfort warm suitabl cool weather soft smooth good qualiti ordorless machin washabl good home use ye',
#  'good fit qualiti',
#  '',
#  'fantast boot price',
#  'xl order unlik similar extra larg shirt order time made ridicul small mayb xl child size',
#  'got hat today well made fit like glove get lot wear time great hat money',
#  'happi feet love excel color live area could wear sandal year round',
#  'friend love durabl look good j',
#  'danner els say',
#  'pretti sturdi chain shini bright love longer length',
#  'fact got littl discolor love buy',
#  'great',
#  'awesom short comfort fit',
#  'like lot',
#  'love old school calcul watch fun exactli like pictur even got water still work might abl tax last night figur old johnni cash',
#  'shoe perfect fit insol comfort feel great walk day would definit recommend',
#  'boot footb comfort right box upper need littl break time keep feet nice dri waterproof overal great boot second time bought',
#  'perfect fit',
#  'ok',
#  'love hat run small forewarn month old small longer fit month hat thank month hat readi hat cute keep littl one nice cozi',
#  'brought whim impress craftsmen ship fabric great item great price',
#  'great shoe nd keem expect great old one',
#  'costum expect good costum fit okay lb boot top would stretch complet cover shoe crotch littl tight fine costum cowork love',
#  'fit well work fine trip',
#  'happi shoe',
#  'price sock get job done fit well comfort wear gold toe gener purpos sock year complaint issu see particular line seem lack thick seen previou year howev wash dri shrunk bit feel like bit substanc',
#  'want shoe cover keep carpet clean hous market job',
#  'nice pant pleasantli surpris qualiti pant',
#  'good',
#  'fit expect littl room grow',
#  ...]

# %% [markdown]
# # TF_IDF (term frequency-inverse document frequency)

# %%
vect = TfidfVectorizer(min_df = 5).fit(corpus)
features = vect.transform(corpus)

# %%
labels = df.iloc[:, 3] 
#train test split
features_train, features_test, labels_train, labels_test = train_test_split(features, labels, random_state = 42)

# %%
model = LogisticRegression()
model.fit(features_train, labels_train)
# Out:
# C:\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
predictions = model.predict(features_test)

roc_auc_score(labels_test, predictions)
# Out:
# 0.8807043979921422

# %%
pkl_filename = "pickle_model.pkl"

with open(pkl_filename, 'wb') as file:
    pickle.dump(model, file)

# %%
with open(pkl_filename, 'rb') as file:
    pickle_model = pickle.load(file)

# %%
predictions = pickle_model.predict(features_test)

roc_auc_score(labels_test, predictions)
# Out:
# 0.8807043979921422
